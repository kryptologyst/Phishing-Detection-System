# %% [markdown]
# # Phishing Detection System - Quick Start
#
# This notebook demonstrates the basic usage of the phishing detection system.
#
# ## Disclaimer
# This is a research and educational tool only. Not intended for production security operations.

# %%
# Import required libraries
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Add src to path
sys.path.append('src')

from src.phishing_detector import PhishingDetector

# %% [markdown]
# ## 1. Initialize the System

# %%
# Initialize the phishing detection system
detector = PhishingDetector()
print("✅ Phishing detection system initialized")
